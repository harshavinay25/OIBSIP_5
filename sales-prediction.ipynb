# %% [markdown]
# SALES PREDICTION USING PYTHON

# %% [markdown]
# IMPORTING NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOADING THE DATA SET

# %%
df=pd.read_csv('/Users/harshavinaykotni/Desktop/python /oasis-sip-/Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Observation :The mean is highest in Tv , The mean is lowest on Radio , The Max sales is 27 and min is 1.6

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# CHECKING FOR NULL VALUES

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# REMOVING THE COLUMN UNNAMED

# %%
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# DATA VIZUALIZATION

# %%
sns.pairplot(df, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', kind='scatter')
plt.show()

# %%
sns.heatmap(df.corr(),annot = True)
plt.show()

# %% [markdown]
# TRAINING AND TESTING THE MODEL

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['TV']],df[['Sales']],test_size=0.2,random_state=0)

# %%
x_train
# Out:
#         TV
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [160 rows x 1 columns]

# %%
x_test
# Out:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0

# %%
y_train
# Out:
#      Sales
# 134   10.8
# 66     9.5
# 26    15.0
# 113   15.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]

# %%
y_test
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107    8.7
# 98    25.4
# 177   11.7
# 182    8.7
# 5      7.2
# 146   13.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   10.5
# 154   15.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    14.9
# 159   12.9
# 60     8.1
# 123   15.2
# 179   12.6
# 185   22.6
# 122   11.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     12.9
# 83    13.6
# 106    7.2

# %% [markdown]
# USING LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
res=model.predict(x_test)

# %%
print(res)
# Out:
# [[10.47623281]
#  [ 9.59288325]
#  [11.45159795]
#  [20.62095042]
#  [15.12301956]
#  [ 9.87813155]
#  [ 7.69276154]
#  [18.33896406]
#  [ 8.38747917]
#  [16.383633  ]
#  [19.3143292 ]
#  [11.30437303]
#  [14.49731363]
#  [15.93275666]
#  [10.8074889 ]
#  [12.82263008]
#  [19.51216269]
#  [ 7.32469923]
#  [10.72927566]
#  [17.11055607]
#  [20.52433406]
#  [13.74738665]
#  [15.34845773]
#  [13.35171966]
#  [ 9.75391052]
#  [12.95605267]
#  [14.91138373]
#  [16.72409064]
#  [17.59823864]
#  [ 8.44728929]
#  [10.41182191]
#  [16.44344313]
#  [20.20688032]
#  [18.41257652]
#  [ 7.8997966 ]
#  [ 8.15283944]
#  [10.03455803]
#  [15.61070213]
#  [10.43942658]
#  [ 8.44268851]]

# %%
model.coef_
# Out:
# array([[0.04600779]])

# %%
model.intercept_
# Out:
# array([7.29249377])

# %%
0.04600779 * 69.2 + 7.29249377
# Out:
# 10.476232838

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,7.29249377 + 0.04600779 * x_test,'r')
plt.show()
